# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn import metrics

# %%
jazz_df = pd.read_csv('jazztracks.csv')
rock_df = pd.read_csv('rocktracks.csv')
electronic_df = pd.read_csv('electronictracks.csv')
hiphop_df = pd.read_csv('hiphoptracks.csv')
country_df = pd.read_csv('countrytracks.csv')
classical_df = pd.read_csv('classicaltracks.csv')

# %%
jazz_df['genre'] = 'Jazz'

# %%
jazz_df['target'] = 0

# %%
rock_df['genre'] = 'Rock'

# %%
rock_df['target'] = 1

# %%
electronic_df['genre'] = 'electronic'

# %%
hiphop_df['genre'] = 'hiphop'

# %%
country_df['genre'] = 'country'

# %%
classical_df['genre'] = 'classical'

# %%
spotify_df = pd.merge(rock_df, jazz_df, how="outer")

# %%
spotify_df
# Out:
#        Unnamed: 0          track_name          album               artist  \
# 0               0       One More Year  The Slow Rush          Tame Impala
# 1               1    Vámonos de Viaje           BACH      Bandalos Chinos
# 2               2               Sofia       Immunity               Clairo
# 3               3        Sadnecessary   Sadnecessary         Milky Chance
# 4               4          Closedloop   Boomerang EP          Elliot Moss
# ...           ...                 ...            ...                  ...
# 10135        5041  The Theme - Take 1        Workin'  Miles Davis Quintet
# 10136        5042       Trane's Blues        Workin'  Miles Davis Quintet
# 10137        5043       Ahmad's Blues        Workin'  Miles Davis Quintet
# 10138        5044         Half Nelson        Workin'  Miles Davis Quintet
# 10139        5045  The Theme - Take 2        Workin'  Miles Davis Quintet
#
#       release_date  length  popularity  danceability  energy  key  ...  mode  \
# ...

# %%
spotify_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10140 entries, 0 to 10139
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        10140 non-null  object
#  1   album             10140 non-null  object
#  2   artist            10140 non-null  object
#  3   release_date      10140 non-null  object
#  4   length            10140 non-null  int64
#  5   popularity        10140 non-null  int64
#  6   danceability      10140 non-null  float64
#  7   energy            10140 non-null  float64
#  8   key               10140 non-null  int64
#  9   loudness          10140 non-null  float64
#  10  mode              10140 non-null  int64
#  11  speechiness       10140 non-null  float64
#  12  acousticness      10140 non-null  float64
#  13  instrumentalness  10140 non-null  float64
#  14  liveness          10140 non-null  float64
#  15  valence           10140 non-null  float64
# ...

# %%
spotify_df.to_csv("spotifytracks.csv")

# %%
mc_spotify_df = pd.read_csv('5classspotifytracks.csv')

# %%
mc_spotify_df = pd.merge(mc_spotify_df, classical_df, how='outer')

# %%
mc_spotify_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
mc_spotify_df.to_csv("6classspotifytracks.csv")

# %%
mc_spotify_df
# Out:
#        Unnamed: 0.1                                    track_name  \
# 0               0.0                                 One More Year
# 1               1.0                              Vámonos de Viaje
# 2               2.0                                         Sofia
# 3               3.0                                  Sadnecessary
# 4               4.0                                    Closedloop
# ...             ...                                           ...
# 27250           NaN      Suite in G Minor, BWV 995: II. Allemande
# 27251           NaN      Suite in G Minor, BWV 995: III. Courante
# 27252           NaN      Suite in G Minor, BWV 995: IV. Sarabande
# 27253           NaN  Suite in G Minor, BWV 995: V. Gavottes 1 & 2
# 27254           NaN          Suite in G Minor, BWV 995: VI. Gigue
#
#                   album                 artist release_date  length  \
# 0         The Slow Rush            Tame Impala   2020-02-14  324013
# ...

# %%
testingmodel_df = pd.read_csv('testingmodel.csv')
testingmodel_df.head(50)
# Out:
#     Unnamed: 0                                         track_name  \
# 0            0  Dvořák: From the Bohemian Forest, Op. 68, B. 1...
# 1            1          Suite bergamasque, L.75: 3. Clair de lune
# 2            2              Le Jardin Féerique from Ma Mère L'oye
# 3            3  Zion Hört Die Wächter Singen (From "Cantata Wa...
# 4            4         Dawn - From "Pride & Prejudice" Soundtrack
# 5            5                                              Agape
# 6            6                            Rêverie, L. 68: Rêverie
# 7            7                       Allegro appassionato, Op. 43
# 8            8  The Carnival of the Animals, R. 125: XIII. The...
# 9            9  Elgar: Cello Concerto in E Minor, Op. 85: I. A...
# 10          10                                               Bird
# 11          11                               12.00 - Original Mix
# 12          12                                              Miura
# ...

# %%
testingmodel_df['genre'] = 'classical'

# %%
testingmodel_df['genre'].iloc[50:60] = 'country'

# %%
testingmodel_df.tail(50)
# Out:
#     Unnamed: 0                                         track_name  \
# 10          10                                               Bird
# 11          11                               12.00 - Original Mix
# 12          12                                              Miura
# 13          13                                              Melt!
# 14          14                                  Strange Overtones
# 15          15              Colder & Closer - Suzanne Kraft Remix
# 16          16  Balearic Incarnation (Todd Terjes Extra Døll Mix)
# 17          17                                           Gou Talk
# 18          18                                       I Feel Space
# 19          19                                         Variations
# 20          20                          Tapestry from an Asteroid
# 21          21                           It Never Entered My Mind
# 22          22                                          Chameleon
# ...

# %%
testingmodel_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
testingmodel_df.to_csv("testingmodelfinal.csv")
